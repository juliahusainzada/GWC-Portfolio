# %% [markdown]
# ##<font color='CC99FF'>**Rock, Paper, Scissors Game Tutorial!**
# ####Developed by Julia Husainzada, Girls Who Code Technical Developer
#
# **In this tutorial, we'll create a simple Rock, Paper, Scissors game in Python!** You’ll learn how to:
# 1. Take input from the user.
# 2. Generate random choices for the computer.
# 3. Keep track of scores.
# 4. Determine the winner.
# 5. Decide to play again.
#
# Let's get started! ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'
#
# ![0_3oJdSb7B26rt3xjJ.png](data:image/png;base64,...)

# %% [markdown]
# #### <font color='CC99FF'>Step 0️⃣: **Importing Necessary Libraries**

# %% [markdown]
# We'll specifically be using the ```random``` libraries ```choice()``` method to generate a random choice for the computer - either rock, paper, or scissors!: [*Learn more about it here!*](https://www.w3schools.com/python/ref_random_choice.asp)
#
#
# ![girl-reading-book-in-school-library-illustration-download-svg-png-gif-file-formats--student-activities-pack-education-illustrations-3561229.png](data:image/png;base64,...)

# %%
import random

# %% [markdown]
# ## <font color='CC99FF'>Let's build our game!
#
# ![RPSLS.webp](data:image/webp;base64,...)

# %% [markdown]
# ####<font color='CC99FF'>Step 1️⃣: **Setting Up the Choices List**
#
# In this step, you’ll need to create a list called choices that contains the three possible options: ```"rock"```, ```"paper"```, and ```"scissors"```. This list will be used later when the computer needs to randomly pick one of these options.
#
# 📝 What to do: Define a list named choices and include the three options as strings. Think about why we need this list for the game. What happens if we didn’t use a list?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %%
# Step 1
choices = ["___", "___", "___"]

# Step 2
number_of_rounds = int(input("____"))

# Step 3
player_score = ____
computer_score = ____

# Step 4
for round_num in range(___):
  # Step 5:
  user_choice = input("____").____

  # Step 6:
  computer_choice = random.choice(____)

  # Step 7:
  print("You chose:", ____)
  print("Computer chose:", ____)

  # Step 8:
  if user_choice == ____:
    print("This round is a tie!")
  elif (user_choice == "rock" and computer_choice == "____") or \
       (user_choice == "____" and computer_choice == "rock") or \
       (user_choice == "scissors" and computer_choice == "____"):
          print("You win this round!")
          player_score += 1
  else:
    print("Computer wins this round!")
    computer_score += 1

  # Step 9:
  print(f"Your score: {player_score}")
  print(f"Computer score: {computer_score}\n")

# Step 10:
if player_score > ____:
    print("Congratulations! You won the game!")
elif player_score < ____:
    print("Computer wins the game! Better luck next time.")
else:
    print("The game is a tie!")

# %% [markdown]
# ####<font color='CC99FF'>Step 2️⃣: **Asking for the Number of Rounds**
# Here, we want the player to choose how many rounds they would like to play. To do that, we will prompt them to enter a number. Since ```input()``` returns a string, you need to convert it to an integer using ```int()```. This number will decide how long the game lasts!
#
# 📝 **What to do**: Write a line that asks the user to input the number of rounds and stores it as an integer. Why do we need to convert it to an integer?
#
# ˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 3️⃣: **Initializing the Scores**
#
# Both the player and the computer start with a score of zero. These variables will keep track of their scores throughout the game.
#
# 📝 What to do: Create two variables, ```player_score``` and ```computer_score```, and set them both to zero. Why is it important to keep track of scores?
#
# ˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 4️⃣: **Creating the Game loop**
#
# Now, you’ll write a loop that repeats for the number of rounds the player selected. Each loop represents a single round of the game.
#
# 📝 What to do: Use a for loop that runs the number of times the player chose. How does this loop help us repeat the game for multiple rounds?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 5️⃣: **Player's Choice**
#
# In this step, you’ll prompt the player to choose ```"rock"```, ```"paper"```, or ```"scissors"```. The input should be case-insensitive, so you’ll use ```.lower()``` to handle that.
#
# 📝 **What to do**: Write a line that asks the player for their choice and converts it to lowercase. Why might you want to make the input case-insensitive?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 6️⃣: **Computer's Choice**
# The computer needs to make a random choice between ```"rock"```, ```"paper"```, and ```"scissors"```. Use ```random.choice()``` to pick from the choices list.
#
# 📝 **What to do**: Write a line that lets the computer randomly choose between the three options in the choices list. How does randomness add challenge to the game?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 7️⃣: **Displaying the Choices**
#
# Now that both the player and the computer have made their choices, print them out so that the player can see what happened.
#
# 📝 **What to do**: Use ```print()``` to display both the player’s and computer’s choices. Why do we need to show these choices after each round?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 8️⃣: **Determining the Round Winner**
#
# Here, we will determine if the round is a tie or if someone won. We’ll use ```if``` statements to compare the player’s and computer’s choices and adjust the scores accordingly.
#
# 📝 **What to do**: Write an ```if-elif-else``` block that checks whether it’s a tie, the player wins, or the computer wins. Then update the scores. Why is it important to handle all possible outcomes (tie, player win, computer win)?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 9️⃣: **Displaying Scores After Each Round**
# After determining the winner of the round, print out the updated scores for both the player and the computer.
#
# 📝 **What to do**: Use ```print()``` to show the current scores after each round. Why might showing the scores after every round make the game more engaging?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ####<font color='CC99FF'>Step 🔟: **Determining the Overall Winner**
# Once all rounds have been played, compare the final scores to see who won the game. If the scores are equal, it’s a tie!
#
# 📝 **What to do**: Write an ```if-elif-else``` block to check the final scores and announce the winner. Why is it important to evaluate the final scores at the end?
#
# ˏˋ°•*⁀➷'*•.¸♡ ♡¸.•*'

# %% [markdown]
# ##<font color='CC99FF'>**You did it! Congrats!** 🎉
